# %%
# importing libraries
import pandas as pd
import scipy
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\hp\Desktop\Machine Learning\practice\pima indian diabetes\diabetes.csv')
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# STATISTICAL ANALYSIS

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %% [markdown]
# CHECKING FOR OUTLIERS

# %%
import matplotlib.pyplot as plt

# Create a figure and a 9-row subplot grid, each subplot having a size of 7x17 inches, with a DPI of 95
fig, axs = plt.subplots(9, 1, dpi=95, figsize=(7, 17))

# Loop through the dataframe columns using enumerate to get both index (i) and column name (col)
for i, col in enumerate(df.columns):
    # Create a horizontal boxplot for the current column's data
    axs[i].boxplot(df[col], vert=False)
    
    # Set the y-axis label to be the column name for each subplot
    axs[i].set_ylabel(col)
    
    # Optionally add a label to the x-axis (this can help if the scales differ across plots)
    axs[i].set_xlabel('Values')

# Adjust the layout so that subplots do not overlap (automatically handles spacing between subplots)
plt.tight_layout()

# Show the plot with all subplots displayed in a single figure
plt.show()

# %%
import numpy as np

# Step 1: Remove outliers from 'Insulin' column
# Identify the quartiles for 'Insulin'
q1, q3 = np.percentile(df['Insulin'], [25, 75])
# Calculate the interquartile range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop rows where 'Insulin' is outside the bounds
clean_data = df[(df['Insulin'] >= lower_bound) & (df['Insulin'] <= upper_bound)]

# Step 2: Remove outliers from 'Pregnancies' column
# Identify the quartiles for 'Pregnancies'
q1, q3 = np.percentile(clean_data['Pregnancies'], [25, 75])
# Calculate the IQR
iqr = q3 - q1
# Calculate the lower and upper bounds for outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop rows where 'Pregnancies' is outside the bounds
clean_data = clean_data[(clean_data['Pregnancies'] >= lower_bound) 
                        & (clean_data['Pregnancies'] <= upper_bound)]

# Step 3: Remove outliers from 'Age' column
# Identify the quartiles for 'Age'
q1, q3 = np.percentile(clean_data['Age'], [25, 75])
# Calculate the IQR
iqr = q3 - q1
# Calculate the lower and upper bounds for outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop rows where 'Age' is outside the bounds
clean_data = clean_data[(clean_data['Age'] >= lower_bound) 
                        & (clean_data['Age'] <= upper_bound)]

# Step 4: Remove outliers from 'Glucose' column
# Identify the quartiles for 'Glucose'
q1, q3 = np.percentile(clean_data['Glucose'], [25, 75])
# Calculate the IQR
iqr = q3 - q1
# Calculate the lower and upper bounds for outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop rows where 'Glucose' is outside the bounds
clean_data = clean_data[(clean_data['Glucose'] >= lower_bound) 
                        & (clean_data['Glucose'] <= upper_bound)]

# Step 5: Remove outliers from 'BloodPressure' column
# Identify the quartiles for 'BloodPressure'
q1, q3 = np.percentile(clean_data['BloodPressure'], [25, 75])
# Calculate the IQR
iqr = q3 - q1
# Calculate the lower and upper bounds for outliers (using 0.75 factor)
lower_bound = q1 - (0.75 * iqr)
upper_bound = q3 + (0.75 * iqr)
# Drop rows where 'BloodPressure' is outside the bounds
clean_data = clean_data[(clean_data['BloodPressure'] >= lower_bound) 
                        & (clean_data['BloodPressure'] <= upper_bound)]

# Step 6: Remove outliers from 'BMI' column
# Identify the quartiles for 'BMI'
q1, q3 = np.percentile(clean_data['BMI'], [25, 75])
# Calculate the IQR
iqr = q3 - q1
# Calculate the lower and upper bounds for outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop rows where 'BMI' is outside the bounds
clean_data = clean_data[(clean_data['BMI'] >= lower_bound) 
                        & (clean_data['BMI'] <= upper_bound)]

# Step 7: Remove outliers from 'DiabetesPedigreeFunction' column
# Identify the quartiles for 'DiabetesPedigreeFunction'
q1, q3 = np.percentile(clean_data['DiabetesPedigreeFunction'], [25, 75])
# Calculate the IQR
iqr = q3 - q1
# Calculate the lower and upper bounds for outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop rows where 'DiabetesPedigreeFunction' is outside the bounds
clean_data = clean_data[(clean_data['DiabetesPedigreeFunction'] >= lower_bound) 
                        & (clean_data['DiabetesPedigreeFunction'] <= upper_bound)]

# %%
# Step 1: Calculate the correlation matrix for the DataFrame
corr = df.corr()

# Step 2: Create a figure with a specific DPI for better resolution
plt.figure(dpi=130)

# Step 3: Generate a heatmap of the correlation matrix
# 'annot=True' displays the correlation coefficients on the heatmap
# 'fmt=".2f"' formats the correlation values to two decimal places
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', cbar_kws={'label': 'Correlation Coefficient'})

# Step 4: Display the heatmap
plt.show()

# %%
# Sort the correlations with the 'Outcome' column in descending order
sorted_corr = corr['Outcome'].sort_values(ascending=False)

# Display the sorted correlations
print(sorted_corr)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# Name: Outcome, dtype: float64

# %% [markdown]
# Check Outcomes Proportionality

# %%
# Create a pie chart using the value counts of the 'Outcome' column
plt.pie(df.Outcome.value_counts(), 
        labels=['Diabetes', 'Not Diabetes'],  # Custom labels for the categories
        autopct='%.f%%',                      # Display percentages with no decimals, and include the percentage sign
        shadow=True)                          # Add a shadow to the pie chart for visual effect

# Set the title for the pie chart
plt.title('Outcome Proportionality')

# Show the pie chart
plt.show()

# %% [markdown]
# **Step 6: Separate independent features and Target Variables**

# %%
# separate array into input and output components
X = df.drop(columns =['Outcome'])
Y = df.Outcome

# %% [markdown]
# **Step 7: Normalization or Standardization**
# Normalization
#
# MinMaxScaler scales the data so that each feature is in the range [0, 1].
# It works well when the features have different scales and the algorithm being used is sensitive to the scale of the features, such as k-nearest neighbors or neural networks.
# Rescale your data using scikit-learn using the MinMaxScaler.

# %%
# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# learning the statistical parameters for each of the data and transforming
rescaledX = scaler.fit_transform(X)
rescaledX[:5]
# Out:
# array([[0.35294118, 0.74371859, 0.59016393, 0.35353535, 0.        ,
#         0.50074516, 0.23441503, 0.48333333],
#        [0.05882353, 0.42713568, 0.54098361, 0.29292929, 0.        ,
#         0.39642325, 0.11656704, 0.16666667],
#        [0.47058824, 0.91959799, 0.52459016, 0.        , 0.        ,
#         0.34724292, 0.25362938, 0.18333333],
#        [0.05882353, 0.44723618, 0.54098361, 0.23232323, 0.11111111,
#         0.41877794, 0.03800171, 0.        ],
#        [0.        , 0.68844221, 0.32786885, 0.35353535, 0.19858156,
#         0.64232489, 0.94363792, 0.2       ]])

# %% [markdown]
# **Standardization**
# Standardization is a useful technique to transform attributes with a Gaussian distribution and differing means and standard deviations to a standard Gaussian distribution with a mean of 0 and a standard deviation of 1.
# We can standardize data using scikit-learn with the StandardScaler class.
# It works well when the features have a normal distribution or when the algorithm being used is not sensitive to the scale of the features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)
rescaledX[:5]
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075,  0.90726993, -0.69289057,
#          0.20401277,  0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575,  0.53090156, -0.69289057,
#         -0.68442195, -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, -1.28821221, -0.69289057,
#         -1.10325546,  0.60439732, -0.10558415],
#        [-0.84488505, -0.99820778, -0.16054575,  0.15453319,  0.12330164,
#         -0.49404308, -0.92076261, -1.04154944],
#        [-1.14185152,  0.5040552 , -1.50468724,  0.90726993,  0.76583594,
#          1.4097456 ,  5.4849091 , -0.0204964 ]])
